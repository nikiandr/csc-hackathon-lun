# %%
import itertools
import os
from pathlib import Path

import numpy as np
import pandas as pd
import imagehash
import skimage
from PIL import Image, UnidentifiedImageError
from tqdm.auto import tqdm as tn

from pandarallel import pandarallel


tn.pandas()
pandarallel.initialize(progress_bar=True, nb_workers=os.cpu_count())
# Out:
# INFO: Pandarallel will run on 64 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
# %cd ~/work/dev/Others/yerko/other/csc
# Out:
# /home/jovyan/work/dev/Others/yerko/other/csc

# %%
# DATA_PATH = Path("/kaggle/input/csc-hack-lun-dataset")
# COMP_DATA_PATH = Path("/kaggle/input/csc-hackathon-2023-lunua-task")
# IMAGE_PATH = Path("/kaggle/input/csc-hack-lun-dataset/dataset")
DATA_PATH = Path("data")
COMP_DATA_PATH = Path("data")
IMAGE_PATH = Path("dataset")

TEST_SET = COMP_DATA_PATH / "test-data.csv"
TRAIN_SPLIT = DATA_PATH / "train_split_20perval_grouped_stratified.csv"
VAL_SPLIT = DATA_PATH / "val_split_20perval_grouped_stratified.csv"

IMG_GLOB = "images_*_unpadded/*.jpg"

# %%
def bind_fs(df, path: Path, glob: str):
    mapping = {x.name: x for x in path.glob(glob)}
    return df.applymap(lambda x: mapping.get(x))

# %%
val_df = pd.read_csv(VAL_SPLIT)
val_df[["image_path1", "image_path2"]] = bind_fs(val_df.filter(like="image_url"), IMAGE_PATH, IMG_GLOB)

train_df = pd.read_csv(TRAIN_SPLIT)
train_df[["image_path1", "image_path2"]] = bind_fs(train_df.filter(like="image_url"), IMAGE_PATH, IMG_GLOB)

test_df = pd.read_csv(TEST_SET)
test_df[["image_url1", "image_url2"]] = test_df[["image_url1", "image_url2"]].applymap(lambda x: x.rsplit("/", 1)[-1])
test_df[["image_path1", "image_path2"]] = bind_fs(test_df.filter(like="image_url"), IMAGE_PATH, IMG_GLOB)

# %%
class Predictor:
    def __init__(self, transforms, col1="image_path1", col2="image_path2"):
        self.transforms = transforms
        self._col1 = col1
        self._col2 = col2

    def transform_image(self, img):
        return {k: transform(img) for k, transform in self.transforms.items()}

    def predict(self, row):
        if row[self._col1] is None or row[self._col2] is None:
            # print(row)
            return None
        try:
            img1 = Image.open(row[self._col1])
            img2 = Image.open(row[self._col2])
            hashes1 = self.transform_image(img1)
            hashes2 = self.transform_image(img2)
        except (UnidentifiedImageError, OSError):
            return {}
        hashres = {}
        for k in hashes1:
            try:
                hashres[k] = hashes1[k] - hashes2[k]
            except:
                hashres[k] = np.nan
        hashres["left_grayscale"] = img1.mode == "L"
        hashres["right_grayscale"] = img2.mode == "L"
        hashres["left_height"] = img1.height
        hashres["right_height"] = img2.height
        hashres["left_width"] = img1.width
        hashres["right_width"] = img2.width
        return hashres

# %% [markdown]
# ## Version 1

# %%
transforms = {
    "ahash_16": lambda x: imagehash.average_hash(x, 16),
    "phash_16_8": lambda x: imagehash.phash(x, hash_size=16, highfreq_factor=8),
    "phash": lambda x: imagehash.phash(x, hash_size=16, highfreq_factor=8),
    "dhash_verical_16": lambda x: imagehash.dhash_vertical(x, hash_size=16),
    "dhash_16": lambda x: imagehash.dhash(x, hash_size=16),
    "colorhash_21": lambda x: imagehash.colorhash(x, binbits=21),
    "colorhash_33": lambda x: imagehash.colorhash(x, binbits=33),
    "colorhash_63": lambda x: imagehash.colorhash(x, binbits=63),
    "colorhash_123": lambda x: imagehash.colorhash(x, binbits=123),
    "whash_16_haar": lambda x: imagehash.whash(x, 16, mode="haar"),
    "whash_16_db4": lambda x: imagehash.whash(x, 16, mode="db4"),
}

predictor = Predictor(transforms)
features = train_df.parallel_apply(predictor.predict, axis=1)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1133), Label(value='0 / 1133'))), …

# %%
f = pd.Series(features, index=train_df.index)
f[f.isna()] = [{} for x in f[f.isna()]]

train_df = pd.concat([train_df, pd.DataFrame(f.to_list())], axis=1)
train_df.to_csv("train_df_with_features_v1.1.csv", index=False)

# %%
f = val_df.parallel_apply(predictor.predict, axis=1)

val_df = pd.concat([val_df, pd.DataFrame(f.to_list())], axis=1)
val_df.to_csv("val_df_with_features_v1.1.csv", index=False)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=284), Label(value='0 / 284'))), HB…

# %%
f = test_df.parallel_apply(predictor.predict, axis=1)

test_df = pd.concat([test_df, pd.DataFrame(f.to_list())], axis=1)
test_df.to_csv("test_df_with_features_v1.1.csv", index=False)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=355), Label(value='0 / 355'))), HB…

# %% [markdown]
# ## Version 2

# %%
def butterworth_pil_phash(img, cutoff_frequency_ratio, high_pass, order, hash_size=16, highfreq_factor=8):
    arr = np.array(img.convert('RGB'))
    res = skimage.filters.butterworth(arr,
                                      cutoff_frequency_ratio,
                                      high_pass,
                                      order,
                                      channel_axis=-1,
                                    #   npad=32
                                      )
    pil_res = Image.fromarray(res, mode='RGB')
    hash_res = imagehash.phash(pil_res, hash_size=hash_size, highfreq_factor=highfreq_factor)
    return hash_res

# %%
cutoffs = [0.02, 0.08, 0.16]
high_passes = [True, False]
orders = [1, 3, 5, 8]

# %%
bw_transforms = {
    f"phash_16_8_bw_c{cutoff}_hp{high_pass}_order{order}" : 
        lambda x: butterworth_pil_phash(
            x,
            cutoff,
            high_pass,
            order
        )   
    for (cutoff, high_pass, order) in itertools.product(cutoffs, high_passes, orders)
}
bw_transforms
# Out:
# {'phash_16_8_bw_c0.02_hpTrue_order1': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.02_hpTrue_order3': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.02_hpTrue_order5': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.02_hpTrue_order8': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.02_hpFalse_order1': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.02_hpFalse_order3': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.02_hpFalse_order5': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.02_hpFalse_order8': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.08_hpTrue_order1': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.08_hpTrue_order3': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.08_hpTrue_order5': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.08_hpTrue_order8': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.08_hpFalse_order1': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.08_hpFalse_order3': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.08_hpFalse_order5': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.08_hpFalse_order8': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.16_hpTrue_order1': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.16_hpTrue_order3': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.16_hpTrue_order5': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.16_hpTrue_order8': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.16_hpFalse_order1': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.16_hpFalse_order3': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.16_hpFalse_order5': <function __main__.<dictcomp>.<lambda>(x)>,
#  'phash_16_8_bw_c0.16_hpFalse_order8': <function __main__.<dictcomp>.<lambda>(x)>}

# %%
transforms = {
    "ahash_16": lambda x: imagehash.average_hash(x, 16),
    "phash_16_8": lambda x: imagehash.phash(x, hash_size=16, highfreq_factor=8),
    "phash": lambda x: imagehash.phash(x, hash_size=16, highfreq_factor=8),
    "dhash_verical_16": lambda x: imagehash.dhash_vertical(x, hash_size=16),
    "dhash_16": lambda x: imagehash.dhash(x, hash_size=16),
    "colorhash_21": lambda x: imagehash.colorhash(x, binbits=21),
    "colorhash_33": lambda x: imagehash.colorhash(x, binbits=33),
    "colorhash_63": lambda x: imagehash.colorhash(x, binbits=63),
    "colorhash_123": lambda x: imagehash.colorhash(x, binbits=123),
    "whash_16_haar": lambda x: imagehash.whash(x, 16, mode="haar"),
    "whash_16_db4": lambda x: imagehash.whash(x, 16, mode="db4"),
}
transforms = transforms | bw_transforms

predictor = Predictor(transforms)
features = train_df.parallel_apply(predictor.predict, axis=1)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1133), Label(value='0 / 1133'))), …
# Process ForkPoolWorker-130:
# Process ForkPoolWorker-78:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
# Process ForkPoolWorker-98:
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 741, in apply
#     return self.apply_standard()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-67:
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkPoolWorker-104:
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 868, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 884, in apply_series_generator
#     results[i] = self.f(v)
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
# Process ForkPoolWorker-128:
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/tmp/ipykernel_374652/999389445.py", line 18, in predict
#     hashes2 = self.transform_image(img2)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
# Process ForkPoolWorker-76:
# Process ForkPoolWorker-111:
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/tmp/ipykernel_374652/999389445.py", line 211, in transform_image
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkPoolWorker-121:
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 741, in apply
#     return self.apply_standard()
# Traceback (most recent call last):
#   File "/tmp/ipykernel_374652/999389445.py", line -1, in <dictcomp>
# Process ForkPoolWorker-96:
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/tmp/ipykernel_374652/3815286982.py", line -1, in <lambda>
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 868, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 741, in apply
#     return self.apply_standard()
# Process ForkPoolWorker-114:
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 884, in apply_series_generator
#     results[i] = self.f(v)
#   File "/tmp/ipykernel_374652/2544964441.py", line 3, in butterworth_pil_phash
#     res = skimage.filters.butterworth(arr,
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 868, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/site-packages/skimage/filters/_fft_based.py", line 135, in butterworth
#     butterfilt = fft.irfftn(wfilt * fft.rfftn(image, axes=axes),
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 884, in apply_series_generator
#     results[i] = self.f(v)
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
# Process ForkPoolWorker-72:
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_374652/999389445.py", line 19, in predict
#     except (UnidentifiedImageError, OSError):
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_backend.py", line 17, in __ua_function__
#     @staticmethod
# Process ForkPoolWorker-80:
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-100:
# Process ForkPoolWorker-102:
# Process ForkPoolWorker-91:
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
# Process ForkPoolWorker-126:
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# Process ForkPoolWorker-81:
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
# Process ForkPoolWorker-85:
#   File "/tmp/ipykernel_374652/999389445.py", line -17, in transform_image
# KeyboardInterrupt
# Process ForkPoolWorker-99:
# Process ForkPoolWorker-124:
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-75:
# Traceback (most recent call last):
# Process ForkPoolWorker-117:
# Process ForkPoolWorker-71:
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-109:
# Process ForkPoolWorker-112:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_374652/999389445.py", line 18, in predict
#     hashes2 = self.transform_image(img2)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
# Traceback (most recent call last):
# Process ForkPoolWorker-73:
#   File "/tmp/ipykernel_374652/999389445.py", line -1, in <dictcomp>
# Process ForkPoolWorker-120:
# Traceback (most recent call last):
# Process ForkPoolWorker-92:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/_projects/jup/data/dev/Others/yerko/other/csc/code/12_hash_diff_dataset.ipynb Cell 15 in 1
#      <a href='vscode-notebook-cell://ssh-remote%2Bhobo2.min.org.ua/home/_projects/jup/data/dev/Others/yerko/other/csc/code/12_hash_diff_dataset.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> transforms = transforms | bw_transforms
#      <a href='vscode-notebook-cell://ssh-remote%2Bhobo2.min.org.ua/home/_projects/jup/data/dev/Others/yerko/other/csc/code/12_hash_diff_dataset.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> predictor = Predictor(transforms)
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bhobo2.min.org.ua/home/_projects/jup/data/dev/Others/yerko/other/csc/code/12_hash_diff_dataset.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> features = train_df.parallel_apply(predictor.predict, axis=1)
#
# File /opt/conda/lib/python3.10/site-packages/pandarallel/core.py:307, in parallelize_with_memory_file_system.<locals>.closure(data, user_defined_function, *user_defined_function_args, **user_defined_function_kwargs)
#     299 generation = count()
#     301 while any(
#     302     (
#     303         worker_status == WorkerStatus.Running
#     304         for worker_status in workers_status
#     305     )
#     306 ):
# --> 307     message: Tuple[int, WorkerStatus, Any] = master_workers_queue.get()
#     308     worker_index, worker_status, payload = message
#     309     workers_status[worker_index] = worker_status
#
# File <string>:2, in get(self, *args, **kwds)
#
# File /opt/conda/lib/python3.10/multiprocessing/managers.py:818, in BaseProxy._callmethod(self, methodname, args, kwds)
#     815     conn = self._tls.connection
#     817 conn.send((self._id, methodname, args, kwds))
# --> 818 kind, result = conn.recv()
#     820 if kind == '#RETURN':
#     821     return result
#
# File /opt/conda/lib/python3.10/multiprocessing/connection.py:255, in _ConnectionBase.recv(self)
#     253 self._check_closed()
#     254 self._check_readable()
# --> 255 buf = self._recv_bytes()
#     256 return _ForkingPickler.loads(buf.getbuffer())
#
# File /opt/conda/lib/python3.10/multiprocessing/connection.py:419, in Connection._recv_bytes(self, maxsize)
#     418 def _recv_bytes(self, maxsize=None):
# --> 419     buf = self._recv(4)
#     420     size, = struct.unpack("!i", buf.getvalue())
#     421     if size == -1:
#
# File /opt/conda/lib/python3.10/multiprocessing/connection.py:384, in Connection._recv(self, size, read)
#     382 remaining = size
#     383 while remaining > 0:
# --> 384     chunk = read(handle, remaining)
#     385     n = len(chunk)
#     386     if n == 0:
#
# KeyboardInterrupt:
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkPoolWorker-105:
# Traceback (most recent call last):
# Process ForkPoolWorker-129:
# Process ForkPoolWorker-89:
# Traceback (most recent call last):
# Process ForkPoolWorker-95:
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/tmp/ipykernel_374652/999389445.py", line 108, in transform_image
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-68:
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 741, in apply
#     return self.apply_standard()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/tmp/ipykernel_374652/3815286982.py", line -1, in <lambda>
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 741, in apply
#     return self.apply_standard()
# Process ForkPoolWorker-90:
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkPoolWorker-127:
# Process ForkPoolWorker-83:
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkPoolWorker-108:
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
# Traceback (most recent call last):
# Process ForkPoolWorker-110:
# Process ForkPoolWorker-119:
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 741, in apply
#     return self.apply_standard()
#   File "/tmp/ipykernel_374652/2544964441.py", line 10, in butterworth_pil_phash
#     pil_res = Image.fromarray(res, mode='RGB')
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/tmp/ipykernel_374652/999389445.py", line -1, in <dictcomp>
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-88:
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 868, in apply_standard
#     results, res_index = self.apply_series_generator()
# Process ForkPoolWorker-101:
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 741, in apply
#     return self.apply_standard()
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 741, in apply
#     return self.apply_standard()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-97:
# Process ForkPoolWorker-69:
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 868, in apply_standard
#     results, res_index = self.apply_series_generator()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/site-packages/PIL/Image.py", line 2946, in fromarray
#     strides = arr.get("strides", None)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-87:
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 868, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_374652/3815286982.py", line -1, in <lambda>
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 884, in apply_series_generator
#     results[i] = self.f(v)
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-122:
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 868, in apply_standard
#     results, res_index = self.apply_series_generator()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 868, in apply_standard
#     results, res_index = self.apply_series_generator()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 884, in apply_series_generator
#     results[i] = self.f(v)
# Process ForkPoolWorker-86:
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkPoolWorker-79:
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 884, in apply_series_generator
#     results[i] = self.f(v)
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
# Process ForkPoolWorker-70:
# Process ForkPoolWorker-118:
# Process ForkPoolWorker-115:
# Process ForkPoolWorker-113:
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# Process ForkPoolWorker-103:
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 741, in apply
#     return self.apply_standard()
# Process ForkPoolWorker-125:
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 884, in apply_series_generator
#     results[i] = self.f(v)
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# Process ForkPoolWorker-84:
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 884, in apply_series_generator
#     results[i] = self.f(v)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkPoolWorker-123:
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 741, in apply
#     return self.apply_standard()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/tmp/ipykernel_374652/999389445.py", line 19, in predict
#     except (UnidentifiedImageError, OSError):
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 741, in apply
#     return self.apply_standard()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 868, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 868, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/tmp/ipykernel_374652/999389445.py", line 18, in predict
#     hashes2 = self.transform_image(img2)
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/tmp/ipykernel_374652/999389445.py", line 19, in predict
#     except (UnidentifiedImageError, OSError):
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_374652/999389445.py", line 216, in transform_image
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 868, in apply_standard
#     results, res_index = self.apply_series_generator()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# Process ForkPoolWorker-77:
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 884, in apply_series_generator
#     results[i] = self.f(v)
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/tmp/ipykernel_374652/999389445.py", line 18, in predict
#     hashes2 = self.transform_image(img2)
#   File "/tmp/ipykernel_374652/999389445.py", line 18, in predict
#     hashes2 = self.transform_image(img2)
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_374652/999389445.py", line -47, in transform_image
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 884, in apply_series_generator
#     results[i] = self.f(v)
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/tmp/ipykernel_374652/999389445.py", line 53, in transform_image
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_374652/999389445.py", line -1, in <dictcomp>
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 884, in apply_series_generator
#     results[i] = self.f(v)
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
# Process ForkPoolWorker-74:
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-82:
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/tmp/ipykernel_374652/999389445.py", line 216, in transform_image
#   File "/tmp/ipykernel_374652/999389445.py", line 216, in transform_image
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 741, in apply
#     return self.apply_standard()
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#   File "/tmp/ipykernel_374652/999389445.py", line -1, in <dictcomp>
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
# ...
#   File "/tmp/ipykernel_374652/2544964441.py", line 3, in butterworth_pil_phash
#     res = skimage.filters.butterworth(arr,
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py", line 223, in r2cn
#     return pfft.r2c(tmp, axes, forward, norm, None, workers)
#   File "/tmp/ipykernel_374652/3815286982.py", line -1, in <lambda>
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py", line 223, in r2cn
#     return pfft.r2c(tmp, axes, forward, norm, None, workers)
#   File "/tmp/ipykernel_374652/3815286982.py", line -1, in <lambda>
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_backend.py", line 25, in __ua_function__
#     return fn(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_backend.py", line 25, in __ua_function__
#     return fn(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_backend.py", line 25, in __ua_function__
#     return fn(*args, **kwargs)
#   File "/tmp/ipykernel_374652/999389445.py", line 19, in predict
#     except (UnidentifiedImageError, OSError):
#   File "/tmp/ipykernel_374652/999389445.py", line 19, in predict
#     except (UnidentifiedImageError, OSError):
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py", line 209, in r2cn
#     tmp = _asfarray(x)
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py", line 263, in c2rn
#     return pfft.c2r(tmp, axes, lastsize, forward, norm, None, workers)
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py", line 263, in c2rn
#     return pfft.c2r(tmp, axes, lastsize, forward, norm, None, workers)
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py", line 263, in c2rn
#     return pfft.c2r(tmp, axes, lastsize, forward, norm, None, workers)
#   File "/opt/conda/lib/python3.10/site-packages/pywt/_multidim.py", line 188, in dwtn
#     cA, cD = dwt_axis(x, wav, mode, axis)
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py", line 223, in r2cn
#     return pfft.r2c(tmp, axes, forward, norm, None, workers)
#   File "/opt/conda/lib/python3.10/site-packages/skimage/filters/_fft_based.py", line 135, in butterworth
#     butterfilt = fft.irfftn(wfilt * fft.rfftn(image, axes=axes),
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/tmp/ipykernel_374652/2544964441.py", line 3, in butterworth_pil_phash
#     res = skimage.filters.butterworth(arr,
#   File "/tmp/ipykernel_374652/2544964441.py", line 3, in butterworth_pil_phash
#     res = skimage.filters.butterworth(arr,
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py", line 223, in r2cn
#     return pfft.r2c(tmp, axes, forward, norm, None, workers)
# KeyboardInterrupt
#   File "/tmp/ipykernel_374652/999389445.py", line 56, in transform_image
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py", line 263, in c2rn
#     return pfft.c2r(tmp, axes, lastsize, forward, norm, None, workers)
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py", line 223, in r2cn
#     return pfft.r2c(tmp, axes, forward, norm, None, workers)
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/helper.py", line 92, in _asfarray
#     return np.asarray(x, np.float64)
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py", line 263, in c2rn
#     return pfft.c2r(tmp, axes, lastsize, forward, norm, None, workers)
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_backend.py", line 25, in __ua_function__
#     return fn(*args, **kwargs)
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/site-packages/skimage/filters/_fft_based.py", line 135, in butterworth
#     butterfilt = fft.irfftn(wfilt * fft.rfftn(image, axes=axes),
#   File "/tmp/ipykernel_374652/999389445.py", line 216, in transform_image
#   File "/tmp/ipykernel_374652/999389445.py", line -1, in <dictcomp>
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py", line 209, in r2cn
#     tmp = _asfarray(x)
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_backend.py", line 25, in __ua_function__
#     return fn(*args, **kwargs)
#   File "/tmp/ipykernel_374652/999389445.py", line -1, in <dictcomp>
#   File "/tmp/ipykernel_374652/3815286982.py", line -1, in <lambda>
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 741, in apply
#     return self.apply_standard()
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/helper.py", line 92, in _asfarray
#     return np.asarray(x, np.float64)
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py", line 263, in c2rn
#     return pfft.c2r(tmp, axes, lastsize, forward, norm, None, workers)
#   File "/tmp/ipykernel_374652/3815286982.py", line -1, in <lambda>
#   File "/opt/conda/lib/python3.10/site-packages/skimage/filters/_fft_based.py", line 135, in butterworth
#     butterfilt = fft.irfftn(wfilt * fft.rfftn(image, axes=axes),
#   File "/tmp/ipykernel_374652/2544964441.py", line 3, in butterworth_pil_phash
#     res = skimage.filters.butterworth(arr,
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 868, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/tmp/ipykernel_374652/2544964441.py", line 3, in butterworth_pil_phash
#     res = skimage.filters.butterworth(arr,
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_backend.py", line 25, in __ua_function__
#     return fn(*args, **kwargs)
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/site-packages/skimage/filters/_fft_based.py", line 135, in butterworth
#     butterfilt = fft.irfftn(wfilt * fft.rfftn(image, axes=axes),
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_backend.py", line 25, in __ua_function__
#     return fn(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py", line 209, in r2cn
#     tmp = _asfarray(x)
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py", line 263, in c2rn
#     return pfft.c2r(tmp, axes, lastsize, forward, norm, None, workers)
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 884, in apply_series_generator
#     results[i] = self.f(v)
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/helper.py", line 92, in _asfarray
#     return np.asarray(x, np.float64)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/site-packages/skimage/filters/_fft_based.py", line 135, in butterworth
#     butterfilt = fft.irfftn(wfilt * fft.rfftn(image, axes=axes),
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#   File "/tmp/ipykernel_374652/999389445.py", line 18, in predict
#     hashes2 = self.transform_image(img2)
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_backend.py", line 25, in __ua_function__
#     return fn(*args, **kwargs)
#   File "/tmp/ipykernel_374652/999389445.py", line 216, in transform_image
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py", line 223, in r2cn
#     return pfft.r2c(tmp, axes, forward, norm, None, workers)
#   File "/tmp/ipykernel_374652/999389445.py", line -1, in <dictcomp>
# KeyboardInterrupt
#   File "/tmp/ipykernel_374652/3815286982.py", line -1, in <lambda>
#   File "/tmp/ipykernel_374652/2544964441.py", line 3, in butterworth_pil_phash
#     res = skimage.filters.butterworth(arr,
#   File "/opt/conda/lib/python3.10/site-packages/skimage/filters/_fft_based.py", line 135, in butterworth
#     butterfilt = fft.irfftn(wfilt * fft.rfftn(image, axes=axes),
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_backend.py", line 17, in __ua_function__
#     @staticmethod
# Process ForkPoolWorker-107:
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkPoolWorker-106:
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 741, in apply
#     return self.apply_standard()
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/core.py", line 95, in __call__
#     result = self.work_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 868, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/data_types/dataframe.py", line 32, in work
#     return data.apply(
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 884, in apply_series_generator
#     results[i] = self.f(v)
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/frame.py", line 9558, in apply
#     return op.apply().__finalize__(self, method="apply")
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 741, in apply
#     return self.apply_standard()
#   File "/tmp/ipykernel_374652/999389445.py", line 19, in predict
#     except (UnidentifiedImageError, OSError):
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 868, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "/tmp/ipykernel_374652/999389445.py", line -17, in transform_image
#   File "/opt/conda/lib/python3.10/site-packages/pandas/core/apply.py", line 884, in apply_series_generator
#     results[i] = self.f(v)
#   File "/tmp/ipykernel_374652/999389445.py", line -1, in <dictcomp>
#   File "/opt/conda/lib/python3.10/site-packages/pandarallel/progress_bars.py", line 214, in closure
#     return user_defined_function(
#   File "/tmp/ipykernel_374652/3815286982.py", line -1, in <lambda>
#   File "/tmp/ipykernel_374652/2544964441.py", line 3, in butterworth_pil_phash
#     res = skimage.filters.butterworth(arr,
#   File "/tmp/ipykernel_374652/999389445.py", line 19, in predict
#     except (UnidentifiedImageError, OSError):
#   File "/opt/conda/lib/python3.10/site-packages/skimage/filters/_fft_based.py", line 135, in butterworth
#     butterfilt = fft.irfftn(wfilt * fft.rfftn(image, axes=axes),
#   File "/tmp/ipykernel_374652/999389445.py", line 56, in transform_image
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_backend.py", line 25, in __ua_function__
#     return fn(*args, **kwargs)
#   File "/tmp/ipykernel_374652/999389445.py", line -1, in <dictcomp>
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py", line 223, in r2cn
#     return pfft.r2c(tmp, axes, forward, norm, None, workers)
#   File "/tmp/ipykernel_374652/3815286982.py", line -1, in <lambda>
# KeyboardInterrupt
#   File "/tmp/ipykernel_374652/2544964441.py", line 3, in butterworth_pil_phash
#     res = skimage.filters.butterworth(arr,
#   File "/opt/conda/lib/python3.10/site-packages/skimage/filters/_fft_based.py", line 135, in butterworth
#     butterfilt = fft.irfftn(wfilt * fft.rfftn(image, axes=axes),
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_backend.py", line 25, in __ua_function__
#     return fn(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py", line 223, in r2cn
#     return pfft.r2c(tmp, axes, forward, norm, None, workers)
# KeyboardInterrupt
# Process ForkPoolWorker-132:
# Process ForkPoolWorker-134:
# Process ForkPoolWorker-133:
# Process ForkPoolWorker-131:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/opt/conda/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
#   File "/opt/conda/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.10/multiprocessing/connection.py", line 221, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/opt/conda/lib/python3.10/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/opt/conda/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.10/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
f = pd.Series(features, index=train_df.index)
f[f.isna()] = [{} for x in f[f.isna()]]

train_df = pd.concat([train_df, pd.DataFrame(f.to_list())], axis=1)
train_df.to_csv("train_df_with_features_v2.csv", index=False)
f = val_df.parallel_apply(predictor.predict, axis=1)

val_df = pd.concat([val_df, pd.DataFrame(f.to_list())], axis=1)
val_df.to_csv("val_df_with_features_v2.csv", index=False)
f = test_df.parallel_apply(predictor.predict, axis=1)

test_df = pd.concat([test_df, pd.DataFrame(f.to_list())], axis=1)
test_df.to_csv("test_df_with_features_v2.csv", index=False)
